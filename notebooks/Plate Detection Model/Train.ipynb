# %% [markdown]
# 📊 Stage 1 Split Distribution
# ========================================
# Train :  6597 files (80.0%)
# Val   :   826 files (10.0%)
# Test  :   826 files (10.0%)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.8/978.8 kB 61.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 126.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 45.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 106.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.yaml')

model.train(
    data = '/content/drive/MyDrive/Colab Notebooks/Stage 1/dataset.yaml',
    epochs = 30,
    batch = 16,
    imgsz = 640,
    seed = 42,
    mosaic = 0.0,
    shear = 35,
    pretrained = False,
    device = 'cuda',
    project = '/content/drive/MyDrive/Colab Notebooks/Stage 1/run_n',
    name = 'exp',
    patience = 30
)
# Out:
# Ultralytics 8.3.102 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8s.yaml')

model.train(
    data = '/content/drive/MyDrive/Colab Notebooks/Stage 1/dataset.yaml',
    epochs = 30,
    batch = 16,
    imgsz = 640,
    seed = 42,
    mosaic = 0.0,
    shear = 35,
    pretrained = False,
    device = 'cuda',
    project = '/content/drive/MyDrive/Colab Notebooks/Stage 1/run_s',
    name = 'exp',
    patience = 30
)
# Out:
# Ultralytics 8.3.102 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/Colab Notebooks/Stage 1/run_s/exp/weights/last.pt')

model.train(
    data = '/content/drive/MyDrive/Colab Notebooks/Stage 1/dataset.yaml',
    epochs = 20,
    batch = 32,
    imgsz = 640,
    seed = 42,
    mosaic = 0.0,
    shear = 35,
    pretrained = False,
    device = 'cuda',
    project = '/content/drive/MyDrive/Colab Notebooks/Stage 1/run_s',
    name = 'exp',
    patience = 30
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/Colab Notebooks/Stage 1/run_s/exp2/weights/last.pt')

model.train(
    data = '/content/drive/MyDrive/Colab Notebooks/Stage 1/dataset.yaml',
    epochs = 50,
    batch = 32,
    imgsz = 640,
    seed = 42,
    mosaic = 0.0,
    shear = 35,
    pretrained = False,
    device = 'cuda',
    project = '/content/drive/MyDrive/Colab Notebooks/Stage 1/run_s',
    name = 'exp',
    patience = 30,
    lr0 = 0.02
)
# Out:
# Ultralytics 8.3.109 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.yaml')

model.train(
    data = '/content/drive/MyDrive/Colab Notebooks/Stage 1/dataset.yaml',
    epochs = 30,
    batch = 16,
    imgsz = 640,
    seed = 42,
    mosaic = 0.0,
    shear = 35,
    pretrained = False,
    device = 'cuda',
    project = '/content/drive/MyDrive/Colab Notebooks/Stage 1/run_m',
    name = 'exp',
    patience = 30,
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/Colab Notebooks/Stage 1/run_m/exp/weights/last.pt')

model.train(
    data = '/content/drive/MyDrive/Colab Notebooks/Stage 1/dataset.yaml',
    epochs = 20,
    batch = 32,
    imgsz = 640,
    seed = 42,
    mosaic = 0.0,
    shear = 35,
    pretrained = False,
    device = 'cuda',
    project = '/content/drive/MyDrive/Colab Notebooks/Stage 1/run_m',
    name = 'exp',
    patience = 30,
    lr0 = 0.02
)
# Out:
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/Colab Notebooks/Stage 1/run_m/exp2/weights/last.pt')

model.train(
    data = '/content/drive/MyDrive/Colab Notebooks/Stage 1/dataset.yaml',
    epochs = 50,
    batch = 32,
    imgsz = 640,
    seed = 42,
    mosaic = 0.0,
    shear = 35,
    pretrained = False,
    device = 'cuda',
    project = '/content/drive/MyDrive/Colab Notebooks/Stage 1/run_m',
    name = 'exp',
    patience = 30,
    lr0 = 0.02
)
# Out:
# Ultralytics 8.3.109 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/Colab Notebooks/Stage 1/run_l/exp/weights/last.pt')

model.train(
    data = '/content/drive/MyDrive/Colab Notebooks/Stage 1/dataset.yaml',
    epochs = 20,
    batch = 32,
    imgsz = 640,
    seed = 42,
    mosaic = 0.0,
    shear = 35,
    pretrained = False,
    device = 'cuda',
    project = '/content/drive/MyDrive/Colab Notebooks/Stage 1/run_l',
    name = 'exp',
    patience = 30,
    lr0 = 0.02
)
# Out:
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/Colab Notebooks/Stage 1/run_l/exp2/weights/last.pt')

model.train(
    data = '/content/drive/MyDrive/Colab Notebooks/Stage 1/dataset.yaml',
    epochs = 50,
    batch = 32,
    imgsz = 640,
    seed = 42,
    mosaic = 0.0,
    shear = 35,
    pretrained = False,
    device = 'cuda',
    project = '/content/drive/MyDrive/Colab Notebooks/Stage 1/run_l',
    name = 'exp',
    patience = 30,
    lr0 = 0.02
)
# Out:
# Ultralytics 8.3.109 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/Colab Notebooks/Stage 1/run_l/exp3/weights/last.pt')

model.train(
    data = '/content/drive/MyDrive/Colab Notebooks/Stage 1/dataset.yaml',
    epochs = 50,
    batch = 32,
    imgsz = 640,
    seed = 42,
    mosaic = 0.0,
    shear = 35,
    pretrained = False,
    device = 'cuda',
    project = '/content/drive/MyDrive/Colab Notebooks/Stage 1/run_l',
    name = 'exp',
    patience = 30,
    lr0 = 0.02
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.110 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/Colab Notebooks/Stage 1/run_l/exp3/weights/last.pt')

model.train(
    data = '/content/drive/MyDrive/Colab Notebooks/Stage 1/dataset.yaml',
    epochs = 19,
    batch = 32,
    imgsz = 640,
    seed = 42,
    mosaic = 0.0,
    shear = 35,
    pretrained = False,
    device = 'cuda',
    project = '/content/drive/MyDrive/Colab Notebooks/Stage 1/run_l',
    name = 'exp',
    patience = 30,
    lr0 = 0.02
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.110 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...
